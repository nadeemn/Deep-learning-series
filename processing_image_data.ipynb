# %%
# !wget 'https://media.4-paws.org/b/e/2/d/be2d88ceb9613ac5066bd11dd950faaf2671bef7/VIER%20PFOTEN_2019-03-15_001-1998x1999-600x600.jpg'
# Out:
# --2024-10-12 21:15:15--  https://media.4-paws.org/b/e/2/d/be2d88ceb9613ac5066bd11dd950faaf2671bef7/VIER%20PFOTEN_2019-03-15_001-1998x1999-600x600.jpg
# Resolving media.4-paws.org (media.4-paws.org)... 116.202.15.201
# Connecting to media.4-paws.org (media.4-paws.org)|116.202.15.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29223 (29K) [image/jpeg]
# Saving to: ‘VIER PFOTEN_2019-03-15_001-1998x1999-600x600.jpg’
#
# VIER PFOTEN_2019-03 100%[===================>]  28.54K  --.-KB/s    in 0.1s
#
# 2024-10-12 21:15:16 (194 KB/s) - ‘VIER PFOTEN_2019-03-15_001-1998x1999-600x600.jpg’ saved [29223/29223]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (600, 600, 3)

# %%
print(img)
# Out:
# [[[229 232 237]
#   [229 232 237]
#   [229 232 237]
#   ...
#   [219 218 223]
#   [218 217 222]
#   [218 217 222]]
#
#  [[229 232 237]
#   [229 232 237]
#   [229 232 237]
#   ...
#   [218 217 222]
#   [218 217 222]
#   [218 217 222]]
#
#  [[229 232 237]
#   [229 232 237]
#   [229 232 237]
#   ...
#   [217 216 221]
#   [217 216 221]
#   [217 216 221]]
#
#  ...
#
#  [[158 154  93]
#   [158 154  93]
#   [158 154  93]
#   ...
#   [167 149  99]
#   [168 150 100]
#   [168 150 100]]
#
#  [[157 153  92]
#   [157 153  92]
#   [157 153  92]
#   ...
#   [166 148  98]
#   [167 149  99]
#   [167 149  99]]
#
#  [[156 152  91]
#   [156 152  91]
#   [156 152  91]
#   ...
#   [164 146  96]
#   [165 147  97]
#   [166 148  98]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_resize.jpg')

# %%
img = mpimg.imread('/content/dog_resize.jpg')

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
print(img.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
img_new = plt.imshow(grayscale_image, cmap = 'gray')
plt.show()
